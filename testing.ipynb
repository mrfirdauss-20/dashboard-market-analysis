# %%
from dataset_creator import DatasetCreator

# %%
dt = DatasetCreator('interviewexercisebriefrisqi/modelling_exercise_raw_data.xlsx')
# Out:
# d:\Programming\play\wpp\dataset_creator.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_non_dup['Quarter'] = self.df_non_dup['monthyear'].dt.to_period('Q').astype(str)
# d:\Programming\play\wpp\dataset_creator.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.spend_df['channel'] = self.spend_df['variable'].str.replace('Spend on ', '')

# %%
dt.get_spending_chart_by_brand('Brand 55')

# %%
dt.df_non_dup
# Out:
#        monthyear   business_level     category     brand           variable  \
# 0     2017-01-01  Business Unit 1   Category 1   Brand 1      Spend on meta
# 1     2017-01-01  Business Unit 1   Category 1   Brand 1    Spend on tiktok
# 2     2017-01-01  Business Unit 1   Category 1   Brand 1  Spend on ucontent
# 3     2017-01-01  Business Unit 1   Category 1   Brand 1        Spend on tv
# 4     2017-01-01  Business Unit 1   Category 1   Brand 1   Spend on youtube
# ...          ...              ...          ...       ...                ...
# 45739 2025-05-01  Business Unit 5  Category 20  Brand 74    Spend on tiktok
# 45740 2025-05-01  Business Unit 5  Category 20  Brand 74  Spend on ucontent
# 45741 2025-05-01  Business Unit 5  Category 20  Brand 74        Spend on tv
# 45742 2025-05-01  Business Unit 5  Category 20  Brand 74   Spend on youtube
# 45743 2025-05-01  Business Unit 5  Category 20  Brand 74              Sales
#
#              Amount Quarter
# ...

# %%
dt.get_cluster_of_brand('Brand 55')
# Out:
# Training Cluster Model...
# 'Mid Level'

# %%
dt.plot_brand_cluster()
# Out:
# --- Cluster Thresholds ---
#                     min           max  count          mean
# Tier
# Low Level  2.982719e+09  1.426099e+13     36  5.362102e+12
# Mid Level  1.619350e+13  3.745158e+13     10  2.508690e+13
# Top Whale  6.407374e+13  8.803601e+13      5  7.256444e+13
#                  Sales  Cluster       Tier  Rank
# brand
# Brand 28  8.803601e+13        1  Top Whale     1
# Brand 9   7.182164e+13        1  Top Whale     2
# Brand 20  7.012401e+13        1  Top Whale     3
# Brand 31  6.876682e+13        1  Top Whale     4
# Brand 64  6.407374e+13        1  Top Whale     5
# Brand 63  3.745158e+13        2  Mid Level     6
# Brand 34  3.470968e+13        2  Mid Level     7
# Brand 55  3.153239e+13        2  Mid Level     8
# Brand 57  2.818450e+13        2  Mid Level     9
# Brand 73  2.244482e+13        2  Mid Level    10
# Brand 60  2.176846e+13        2  Mid Level    11
# Brand 21  2.113144e+13        2  Mid Level    12
# ...

# %%
dt.get_is_brand_rely_on_single_channel().groupby('channel')['brand'].nunique().plot.bar()
# Out:
# Brands heavily relying on single channel (>50%) | Filtered by: All, All, All
#         brand channel  Share_Pct   Total
# 21   Brand 13  tiktok      100.0   198.4
# 27   Brand 14      tv      100.0     7.5
# 36   Brand 16  tiktok      100.0   175.8
# 56    Brand 2  tiktok      100.0   200.1
# 131  Brand 33  tiktok      100.0    27.1
# 106  Brand 29  tiktok      100.0    33.2
# 86   Brand 25  tiktok      100.0    78.4
# 70   Brand 22    meta      100.0     0.8
# 151  Brand 37  tiktok      100.0    31.1
# 276   Brand 6  tiktok      100.0   124.7
# 285  Brand 61    meta      100.0     3.5
# 311  Brand 66  tiktok      100.0    26.9
# 326  Brand 69  tiktok      100.0     1.6
# 245  Brand 54    meta      100.0     0.7
# 181  Brand 42  tiktok      100.0   336.1
# 185  Brand 43    meta      100.0     1.8
# 266  Brand 58  tiktok      100.0   431.3
# 82   Brand 24      tv       95.3     8.4
# 142  Brand 35      tv       88.1    20.5
# 127  Brand 32      tv       83.0    26.4
# ...

# %%
dt.plot_channel_seasonality_heatmap()
# Out:
# === Generating Seasonality Heatmaps Per channel ===
# Filter Context: Brand=None, Category=None, Level=None

# %%
dt.plot_channel_seasonality_heatmap(brand_name='Brand 55')
# Out:
# === Generating Seasonality Heatmaps Per channel ===
# Filter Context: Brand=Brand 55, Category=None, Level=None

# %%
dt.plot_spend_vs_sales(brand_name='Brand 55')
# Out:
# === Spend vs Sales Trend Analysis ===
# Filter Context: Brand=Brand 55, Category=None, Level=None

# %%
dt.plot_multi_channel_trends(brand_name='Brand 55')
# Out:
# === Multi-Channel Trend Stack ===
# Filter Context: Brand=Brand 55, Category=None

# %%
dt.test_granger_causality(brand_name='Brand 55', max_lag=6)
# Out:
# === Granger Causality Analysis (Visualized) ===
# Filter Context: Brand=Brand 55, Category=None
# Skipping tiktok: Data is constant/zero (cannot compute causality).
# --- Significant Causal Drivers (p < 0.05) ---
# No channels found with statistically significant causal impact (p < 0.05).
# Note: This suggests Sales may be driven by baseline demand or external factors, not immediate ad spend.

# %%
# !pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 4.8 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.9 MB 4.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.9 MB 4.4 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/9.9 MB 4.2 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.9 MB 4.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/9.9 MB 4.5 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.9 MB 4.5 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/9.9 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 4.8 MB/s  0:00:02
# ...
